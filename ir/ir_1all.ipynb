# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
 nltk.download('punkt')
 nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Shruti\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Shruti\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text =  "Data scientists are analyzing huge datasets and building predictive models. They will be presenting their findings tomorrow."

# %%
 #  Tokenization
 words = word_tokenize(text)
 print("Tokens:", words)
# Out:
# Tokens: ['Data', 'scientists', 'are', 'analyzing', 'huge', 'datasets', 'and', 'building', 'predictive', 'models', '.', 'They', 'will', 'be', 'presenting', 'their', 'findings', 'tomorrow', '.']

# %%
 #  Stop word removal
 stop_words = set(stopwords.words('english'))
 filtered_words = [w for w in words if w.lower() not in stop_words]
 print("After Stopword Removal:", filtered_words)
# Out:
# After Stopword Removal: ['Data', 'scientists', 'analyzing', 'huge', 'datasets', 'building', 'predictive', 'models', '.', 'presenting', 'findings', 'tomorrow', '.']

# %%
ps = PorterStemmer()
stemmed_words = [ps.stem(w) for w in filtered_words]
print("After Stemming:", stemmed_words)
# Out:
# After Stemming: ['data', 'scientist', 'analyz', 'huge', 'dataset', 'build', 'predict', 'model', '.', 'present', 'find', 'tomorrow', '.']
